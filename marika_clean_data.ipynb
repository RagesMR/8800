# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
from scipy import stats
import xlrd

# %%
results_dir = './CSResults.xlsx'
dir_2014 = './2014Clean_Data.xls'

# %%
results = pd.read_excel(results_dir)

# %%
data_2014 = pd.read_excel(dir_2014)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-8d1ec3d05d50> in <module>()
# ----> 1 data_2014 = pd.read_excel(dir_2014)
#
# /Users/marika/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     198
#     199     if not isinstance(io, ExcelFile):
# --> 200         io = ExcelFile(io, engine=engine)
#     201
#     202     return io._parse_excel(
#
# /Users/marika/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     255             self.book = xlrd.open_workbook(file_contents=data)
#     256         elif isinstance(io, compat.string_types):
# ...

# %%
data_2014
# Out:
#           Student Name_SP_TW  School ID_SP_TW  Class Year_SP_TW  \
# 0            Possible Points              NaN               NaN
# 1          Question Category              NaN               NaN
# 2                        NaN              NaN               NaN
# 3      Alzoobaee, SaifEldeen              NaN            2014.0
# 4    Aprilakis, Konstantinos              NaN            2014.0
# 5             Barbuto, Scott              NaN            2014.0
# 6              Barish, Peter              NaN            2014.0
# 7           Bastiaens, Jesse              NaN            2014.0
# 8         Bornstein, Lindsey              NaN            2014.0
# 9           Bryson, Campbell              NaN            2014.0
# 10             Cain, Melissa              NaN            2014.0
# 11        Castaneda, Crystal              NaN            2014.0
# 12        Castillo, Maricela              NaN            2014.0
# 13           Chai, Christina              NaN            2014.0
# ...
