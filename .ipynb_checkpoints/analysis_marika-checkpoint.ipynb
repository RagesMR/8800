# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os.path
import scipy as sp
import scipy.stats
import statsmodels as smr
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
scipy.stats.chisqprob = lambda chisq, df: scipy.stats.chi2.sf(chisq, df)
# Out:
# /Users/marika/anaconda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv('./all_data.csv')

# %%
df.shape
# Out:
# (783, 21)

# %%
df.corr()
# Out:
#                         Student      Year    Result  PersonSatisf_Mean  \
# Student                1.000000 -0.013399 -0.029728          -0.012487
# Year                  -0.013399  1.000000 -0.013142           0.126641
# Result                -0.029728 -0.013142  1.000000           0.194893
# PersonSatisf_Mean     -0.012487  0.126641  0.194893           1.000000
# PersonSatisf_Variance -0.012141 -0.127938 -0.095066          -0.500064
# RecSatisf_Mean        -0.038230  0.265134  0.166238           0.918463
# RecSatisf_Variance    -0.005872 -0.124234 -0.076765          -0.390979
# PPI_Init_Mean         -0.045926 -0.007439  0.067831           0.433947
# PPI_Init_Variance      0.051141 -0.391094 -0.099430          -0.388710
# PPI_Infor_Mean        -0.033697  0.084017  0.057604           0.394035
# PPI_Infor_Variance     0.038110 -0.677735 -0.064380          -0.348113
# PPI_Close_Mean        -0.046458  0.303722  0.106921           0.546254
# PPI_Close_Variance     0.038467 -0.832337 -0.053830          -0.271321
# PE_Hand_Mean          -0.027289 -0.040299  0.022358           0.164131
# PE_Hand_Variance       0.056897 -0.438343  0.046207          -0.115618
# PE_Mod_Mean            0.029393 -0.361712  0.032043           0.211975
# PE_Mod_Variance       -0.010684  0.272280 -0.012280          -0.175526
# PE_Check_Mean          0.017060  0.132741  0.078186           0.411640
# PE_Check_Variance      0.026352 -0.841944  0.021888          -0.081952
# Hx_Mean               -0.032385 -0.069904  0.123246           0.452080
# Hx_Variance            0.056435 -0.813496 -0.008511          -0.186777
#
#                        PersonSatisf_Variance  RecSatisf_Mean  \
# Student                            -0.012141       -0.038230
# Year                               -0.127938        0.265134
# Result                             -0.095066        0.166238
# PersonSatisf_Mean                  -0.500064        0.918463
# PersonSatisf_Variance               1.000000       -0.424411
# RecSatisf_Mean                     -0.424411        1.000000
# RecSatisf_Variance                  0.811130       -0.389942
# PPI_Init_Mean                      -0.196589        0.568147
# PPI_Init_Variance                   0.279155       -0.510069
# PPI_Infor_Mean                     -0.151344        0.545318
# PPI_Infor_Variance                  0.254477       -0.497127
# PPI_Close_Mean                     -0.226551        0.662547
# PPI_Close_Variance                  0.234622       -0.361152
# PE_Hand_Mean                       -0.056745        0.149714
# PE_Hand_Variance                    0.049785       -0.250908
# PE_Mod_Mean                        -0.096698        0.151823
# PE_Mod_Variance                     0.097726       -0.154727
# PE_Check_Mean                      -0.199090        0.365692
# PE_Check_Variance                   0.129705       -0.218552
# Hx_Mean                            -0.182491        0.441083
# Hx_Variance                         0.173135       -0.335445
#
#                        RecSatisf_Variance  PPI_Init_Mean  PPI_Init_Variance  \
# Student                         -0.005872      -0.045926           0.051141
# Year                            -0.124234      -0.007439          -0.391094
# Result                          -0.076765       0.067831          -0.099430
# PersonSatisf_Mean               -0.390979       0.433947          -0.388710
# PersonSatisf_Variance            0.811130      -0.196589           0.279155
# RecSatisf_Mean                  -0.389942       0.568147          -0.510069
# RecSatisf_Variance               1.000000      -0.240798           0.258592
# PPI_Init_Mean                   -0.240798       1.000000          -0.689076
# PPI_Init_Variance                0.258592      -0.689076           1.000000
# PPI_Infor_Mean                  -0.210012       0.920069          -0.601351
# PPI_Infor_Variance               0.237386      -0.451738           0.747974
# PPI_Close_Mean                  -0.245583       0.741916          -0.589222
# PPI_Close_Variance               0.197740      -0.036595           0.484148
# PE_Hand_Mean                    -0.003938       0.149007          -0.091482
# PE_Hand_Variance                 0.090653      -0.251894           0.334111
# PE_Mod_Mean                     -0.057844       0.191045           0.048318
# PE_Mod_Variance                  0.069282      -0.252798           0.063419
# PE_Check_Mean                   -0.114699       0.087768          -0.149723
# PE_Check_Variance                0.123699      -0.194541           0.580654
# Hx_Mean                         -0.201122       0.281611          -0.137053
# Hx_Variance                      0.170392      -0.280714           0.624939
#
#                        PPI_Infor_Mean     ...       PPI_Close_Mean  \
# Student                     -0.033697     ...            -0.046458
# Year                         0.084017     ...             0.303722
# Result                       0.057604     ...             0.106921
# PersonSatisf_Mean            0.394035     ...             0.546254
# PersonSatisf_Variance       -0.151344     ...            -0.226551
# RecSatisf_Mean               0.545318     ...             0.662547
# RecSatisf_Variance          -0.210012     ...            -0.245583
# PPI_Init_Mean                0.920069     ...             0.741916
# PPI_Init_Variance           -0.601351     ...            -0.589222
# PPI_Infor_Mean               1.000000     ...             0.747331
# PPI_Infor_Variance          -0.574566     ...            -0.574100
# PPI_Close_Mean               0.747331     ...             1.000000
# PPI_Close_Variance          -0.086404     ...            -0.504070
# PE_Hand_Mean                 0.121639     ...             0.112183
# PE_Hand_Variance            -0.297508     ...            -0.305733
# PE_Mod_Mean                  0.178259     ...             0.072562
# PE_Mod_Variance             -0.249292     ...            -0.132316
# PE_Check_Mean                0.085628     ...             0.171944
# PE_Check_Variance           -0.253665     ...            -0.365964
# Hx_Mean                      0.278958     ...             0.300975
# Hx_Variance                 -0.341528     ...            -0.446525
#
#                        PPI_Close_Variance  PE_Hand_Mean  PE_Hand_Variance  \
# Student                          0.038467     -0.027289          0.056897
# Year                            -0.832337     -0.040299         -0.438343
# Result                          -0.053830      0.022358          0.046207
# PersonSatisf_Mean               -0.271321      0.164131         -0.115618
# PersonSatisf_Variance            0.234622     -0.056745          0.049785
# RecSatisf_Mean                  -0.361152      0.149714         -0.250908
# RecSatisf_Variance               0.197740     -0.003938          0.090653
# PPI_Init_Mean                   -0.036595      0.149007         -0.251894
# PPI_Init_Variance                0.484148     -0.091482          0.334111
# PPI_Infor_Mean                  -0.086404      0.121639         -0.297508
# PPI_Infor_Variance               0.710962     -0.054165          0.426793
# PPI_Close_Mean                  -0.504070      0.112183         -0.305733
# PPI_Close_Variance               1.000000      0.027920          0.370240
# PE_Hand_Mean                     0.027920      1.000000         -0.535809
# PE_Hand_Variance                 0.370240     -0.535809          1.000000
# PE_Mod_Mean                      0.306760      0.122383          0.126321
# PE_Mod_Variance                 -0.225519     -0.082476         -0.080983
# PE_Check_Mean                   -0.178591      0.121158         -0.086221
# PE_Check_Variance                0.774378      0.017856          0.432023
# Hx_Mean                          0.003664      0.137552         -0.065280
# Hx_Variance                      0.764543     -0.009235          0.457511
#
#                        PE_Mod_Mean  PE_Mod_Variance  PE_Check_Mean  \
# Student                   0.029393        -0.010684       0.017060
# Year                     -0.361712         0.272280       0.132741
# Result                    0.032043        -0.012280       0.078186
# PersonSatisf_Mean         0.211975        -0.175526       0.411640
# PersonSatisf_Variance    -0.096698         0.097726      -0.199090
# RecSatisf_Mean            0.151823        -0.154727       0.365692
# RecSatisf_Variance       -0.057844         0.069282      -0.114699
# PPI_Init_Mean             0.191045        -0.252798       0.087768
# PPI_Init_Variance         0.048318         0.063419      -0.149723
# PPI_Infor_Mean            0.178259        -0.249292       0.085628
# PPI_Infor_Variance        0.168705        -0.043795      -0.180061
# PPI_Close_Mean            0.072562        -0.132316       0.171944
# PPI_Close_Variance        0.306760        -0.225519      -0.178591
# PE_Hand_Mean              0.122383        -0.082476       0.121158
# PE_Hand_Variance          0.126321        -0.080983      -0.086221
# PE_Mod_Mean               1.000000        -0.877947       0.163292
# PE_Mod_Variance          -0.877947         1.000000      -0.095298
# PE_Check_Mean             0.163292        -0.095298       1.000000
# PE_Check_Variance         0.331007        -0.210766      -0.191709
# Hx_Mean                   0.131738        -0.097828       0.282227
# Hx_Variance               0.298656        -0.182904      -0.191737
#
#                        PE_Check_Variance   Hx_Mean  Hx_Variance
# Student                         0.026352 -0.032385     0.056435
# Year                           -0.841944 -0.069904    -0.813496
# Result                          0.021888  0.123246    -0.008511
# PersonSatisf_Mean              -0.081952  0.452080    -0.186777
# PersonSatisf_Variance           0.129705 -0.182491     0.173135
# RecSatisf_Mean                 -0.218552  0.441083    -0.335445
# RecSatisf_Variance              0.123699 -0.201122     0.170392
# PPI_Init_Mean                  -0.194541  0.281611    -0.280714
# PPI_Init_Variance               0.580654 -0.137053     0.624939
# PPI_Infor_Mean                 -0.253665  0.278958    -0.341528
# PPI_Infor_Variance              0.777494 -0.068890     0.796424
# PPI_Close_Mean                 -0.365964  0.300975    -0.446525
# PPI_Close_Variance              0.774378  0.003664     0.764543
# PE_Hand_Mean                    0.017856  0.137552    -0.009235
# PE_Hand_Variance                0.432023 -0.065280     0.457511
# PE_Mod_Mean                     0.331007  0.131738     0.298656
# PE_Mod_Variance                -0.210766 -0.097828    -0.182904
# PE_Check_Mean                  -0.191709  0.282227    -0.191737
# PE_Check_Variance               1.000000  0.068708     0.923345
# Hx_Mean                         0.068708  1.000000    -0.198822
# Hx_Variance                     0.923345 -0.198822     1.000000
#
# [21 rows x 21 columns]

# %%
features = set()

# %%
for i in range(len(df.columns)):
    if 'Mean' in df.columns[i]:
        features.add(df.columns[i])
    #if 'Variance' in df.columns[i]:
        #features.add(df.columns[i])

# %%
smf.logit('Result ~ ' + ('+'.join(features)), data=df).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.082492
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 Result   No. Observations:                  676
# Model:                          Logit   Df Residuals:                      666
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 04 May 2018   Pseudo R-squ.:                  0.1815
# Time:                        14:13:54   Log-Likelihood:                -55.765
# converged:                       True   LL-Null:                       -68.134
#                                         LLR p-value:                  0.003274
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -3.5371      3.169     -1.116      0.264      -9.749       2.675
# PE_Hand_Mean         -0.6335      1.191     -0.532      0.595      -2.968       1.701
# PE_Mod_Mean          -0.0819      1.541     -0.053      0.958      -3.102       2.938
# PPI_Init_Mean        -1.0393      5.044     -0.206      0.837     -10.925       8.846
# RecSatisf_Mean       -2.9618      4.810     -0.616      0.538     -12.390       6.466
# PE_Check_Mean        -0.7314      2.711     -0.270      0.787      -6.044       4.581
# PersonSatisf_Mean    11.0479      4.728      2.337      0.019       1.782      20.314
# Hx_Mean               4.9842      4.402      1.132      0.257      -3.643      13.611
# PPI_Close_Mean        2.1238      3.743      0.567      0.570      -5.212       9.460
# PPI_Infor_Mean       -1.2409      5.749     -0.216      0.829     -12.509      10.028
# =====================================================================================
# """
